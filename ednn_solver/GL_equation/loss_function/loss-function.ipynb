# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import glob
from natsort import natsorted

# %% [markdown]
# Evaluate different loss function
#
# Parametres : 1000 iter
#
# time MSE : 137
# MAE : 108
# RMSE : 125
# MSLE : 117
# Logcosh : 120
# ModifCosineSimil :124
# Huber :

# %%
loss_real = np.loadtxt('./mse/lr1e-4/tanh/adam/output_real.dat',unpack = True)
loss_img = np.loadtxt('./mse/lr1e-4/tanh/adam/output_img.dat',unpack = True)

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

ax.set_yscale('log')

# Surface Plot

ax.plot(loss_real[0],loss_real[1])
ax.plot(loss_img[0],loss_img[1])

ax.legend(['Real', 'Imaginary'])

# Labels
plt.title("MSE - Lr:1e-4 with Exponential Decay - tanh - Adam")
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
