# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import os
import glob
from natsort import natsorted

# %%
x = np.load("./KflowNN/X2",allow_pickle=True)
y = np.load("./KflowNN/Y2",allow_pickle=True)

# %%
u = np.load("./KflowNN/U2",allow_pickle=True)
v = np.load("./KflowNN/V2",allow_pickle=True)

# %%
phi =np.load("./KflowNN/Phi1",allow_pickle=True)
omega = np.load("./KflowNN/Omega1",allow_pickle=True)

# %%
omega
# Out:
# array([[0.8734976 , 0.86360186, 0.8562076 , ..., 0.89782155, 0.88519007,
#         0.87349755],
#        [0.86187726, 0.8540556 , 0.84858435, ..., 0.882126  , 0.8714567 ,
#         0.8618773 ],
#        [0.8572045 , 0.8515448 , 0.84795743, ..., 0.8727617 , 0.86444134,
#         0.8572045 ],
#        ...,
#        [0.9152353 , 0.90194273, 0.8908916 , ..., 0.94438046, 0.92979765,
#         0.9152353 ],
#        [0.89188206, 0.8801054 , 0.87081003, ..., 0.9193232 , 0.905307  ,
#         0.89188206],
#        [0.87349755, 0.8636019 , 0.8562076 , ..., 0.8978215 , 0.8851899 ,
#         0.87349755]], dtype=float32)

# %%
plt.scatter(u[0],v[0])

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111, projection='3d')

# Surface Plot

ax.plot_surface(x, y, u, cmap=cm.jet)

# Labels

ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_zlabel('Z-Axis')
# Out:
# Text(0.5, 0, 'Z-Axis')

# %%
u_list = natsorted(glob.glob('./KflowNN/U*'))
v_list = natsorted(glob.glob('./KflowNN/V*'))

x_list = natsorted(glob.glob('./KflowNN/X*'))
y_list = natsorted(glob.glob('./KflowNN/Y*'))

# %%
for i in range(len(u_list)):
    x = x_list[0]
    y = y_list[0]
    u = u_list[0]
    
    fig = plt.figure(figsize=(6,5))
    ax = fig.add_subplot(111, projection='3d')

    # Surface Plot

    ax.plot_surface(x, y, u, cmap=cm.jet)

    # Labels

    ax.set_xlabel('X-Axis')
    ax.set_ylabel('Y-Axis')
    ax.set_zlabel('Z-Axis')
# Out:
# 82
