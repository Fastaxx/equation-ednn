# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from natsort import natsorted

# %%
loss = np.loadtxt('./Korteweg/output.dat',unpack = True)

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

ax.set_yscale('log')

# Surface Plot

ax.plot(loss[0],loss[1])

ax.legend(['Loss'])

# Labels
plt.title("Loss - Lr:1e-4 with Exponential Decay - 4*20")
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
u = np.load("./Korteweg/U",allow_pickle=True)

# %%
x = np.load("./Korteweg/X",allow_pickle=True)

# %%
plt.plot(u)

# %%
u_list = natsorted(glob.glob('./Korteweg/U*'))

# %%
for elt in u_list:
    u = np.load(elt,allow_pickle=True)
    plt.plot(u)

# %%
u0 = np.load(u_list[0],allow_pickle=True)
u_end= np.load(u_list[-1],allow_pickle=True)

# %%
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(111)

ax.set_yscale('linear')

# Surface Plot

ax.plot(x,u0)
ax.plot(x,u_end)

ax.legend(['Init', 'End'])

# Labels
plt.title("Korteweg - cosine init ")
ax.set_xlabel('x')
ax.set_ylabel('u(x)')
# Out:
# Text(0, 0.5, 'u(x)')
