# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from natsort import natsorted

# %%
u = np.load("./BurgersNN/U0",allow_pickle=True)

# %%
x = np.load("./BurgersNN/X",allow_pickle=True)

# %%
plt.plot(u)

# %%
u_list = natsorted(glob.glob('./BurgersNN/U*'))

# %%
for elt in u_list:
    u = np.load(elt,allow_pickle=True)
    plt.plot(u)
